# %% [markdown]
# ## AoC 2025 - Day 03

# %%
#from icecream import ic

def in_grid(row, col, limits) -> bool:
    return 0 <= row < limits[0] and 0 <= col < limits[1]

banks = open('test.txt').read().split('\n')

banks
# Out:
# ['987654321111111', '811111111111119', '234234234234278', '818181911112111']

# %%
for bank in banks:
    jolts = bank[0]
    battery1_pos = 0
    for b in range(len(bank), len(bank)):
        if bank[b] > jolts:
            jolts = bank[b]

    print(jolts)
    jolts += "0"
    for b in range(bank.find(jolts[0]) + 1, len(bank)):
        if bank[b] > jolts[1]:
            jolts = jolts[0] + bank[b]

    print(jolts)
# Out:
# 9
# 98
# 9
# 90
# 8
# 80
# 9
# 92
