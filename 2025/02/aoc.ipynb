# %% [markdown]
# ## AoC 2024 - Day xx

# %%
#from icecream import ic

def in_grid(row, col, limits) -> bool:
    return 0 <= row < limits[0] and 0 <= col < limits[1]

productIDs = [r.split("-") for r in open('input.txt').read().split(',')]

#productIDs = [["11","22"], ["95","115"]]
#productIDs

# %%
invalid = []
for start,end in productIDs:
    #print(f"Range {start}-{end}")
    for pid in range(int(start), int(end)+1):
        #print(f"  {pid}")
        pid = str(pid)
        if len(pid) % 2 != 0:
            continue
        half = int(len(pid) / 2)
        #print(f"    {half}")
        #print(f"    {pid[:half]} <> {pid[half:]}")
        if pid[:half] == pid[half:]:
            invalid.append(pid)
        # #print(pid[0:1])
        # for chars in range(1, int(len(pid) / 2) + 1):
        #    print(f"    chars {pid[0:chars]}")
        #    pattern_count = pid.count(pid[0:chars])
        #    print(f"    pattern_count {pattern_count}")
        #    if pattern_count * chars == len(pid):
        #        print("    whole pid is pattern?")
        #        invalid.append(pid)

print(invalid)
print(sum(list(map(int,invalid))))
# Out:
# ['516516', '517517', '518518', '519519', '520520', '521521', '522522', '523523', '524524', '525525', '526526', '527527', '528528', '529529', '530530', '531531', '532532', '533533', '534534', '535535', '536536', '537537', '538538', '539539', '540540', '541541', '542542', '543543', '544544', '545545', '546546', '547547', '548548', '549549', '550550', '551551', '552552', '553553', '554554', '555555', '556556', '557557', '558558', '559559', '560560', '561561', '562562', '563563', '564564', '565565', '566566', '567567', '568568', '569569', '570570', '571571', '572572', '573573', '574574', '575575', '576576', '577577', '578578', '579579', '580580', '581581', '582582', '583583', '584584', '585585', '586586', '587587', '588588', '589589', '590590', '591591', '592592', '593593', '594594', '595595', '596596', '597597', '598598', '599599', '600600', '601601', '602602', '603603', '604604', '605605', '606606', '607607', '608608', '609609', '610610', '611611', '612612', '613613', '614614', '615615', '616616', '617617', '618618', '619619', '620620', '621621', '622622', '623623', '624624', '625625', '626626', '627627', '628628', '629629', '630630', '631631', '632632', '633633', '634634', '635635', '636636', '637637', '638638', '639639', '640640', '641641', '642642', '643643', '644644', '645645', '646646', '647647', '648648', '649649', '650650', '651651', '652652', '653653', '654654', '655655', '656656', '657657', '658658', '659659', '660660', '661661', '662662', '663663', '664664', '665665', '666666', '667667', '668668', '711711', '712712', '713713', '714714', '715715', '716716', '717717', '718718', '719719', '720720', '721721', '722722', '723723', '724724', '725725', '726726', '727727', '728728', '729729', '730730', '731731', '732732', '733733', '734734', '735735', '736736', '737737', '738738', '739739', '740740', '741741', '742742', '743743', '744744', '745745', '746746', '747747', '748748', '749749', '750750', '751751', '752752', '753753', '754754', '755755', '756756', '757757', '758758', '759759', '760760', '761761', '762762', '763763', '764764', '765765', '766766', '767767', '768768', '769769', '770770', '771771', '772772', '773773', '774774', '775775', '776776', '777777', '778778', '779779', '780780', '781781', '782782', '783783', '784784', '785785', '786786', '787787', '788788', '789789', '790790', '791791', '792792', '793793', '794794', '795795', '796796', '797797', '798798', '799799', '800800', '801801', '802802', '803803', '804804', '805805', '806806', '807807', '808808', '809809', '810810', '811811', '812812', '813813', '814814', '815815', '816816', '817817', '818818', '819819', '820820', '821821', '822822', '823823', '824824', '825825', '826826', '827827', '828828', '829829', '11', '4375143751', '1515', '1616', '1717', '1818', '1919', '2020', '2121', '2222', '2323', '2424', '2525', '2626', '2727', '2828', '2929', '3030', '3131', '3232', '3333', '29282928', '29292929', '29302930', '12921292', '12931293', '12941294', '12951295', '12961296', '12971297', '12981298', '12991299', '13001300', '13011301', '13021302', '13031303', '13041304', '13051305', '13061306', '55', '66', '77', '88', '99', '5454', '5555', '5656', '5757', '5858', '5959', '6060', '6161', '6262', '6363', '6464', '6565', '6666', '6767', '6868', '6969', '7070', '7171', '7272', '7373', '7474', '7575', '7676', '7777', '7878', '7979', '8080', '8181', '8282', '8383', '8484', '8585', '8686', '8787', '8888', '8989', '9090', '9191', '9292', '9393', '9494', '9595', '9696', '9797', '9898', '9999', '136136', '137137', '138138', '139139', '140140', '141141', '142142', '143143', '144144', '145145', '146146', '147147', '148148', '149149', '150150', '151151', '152152', '153153', '154154', '155155', '156156', '157157', '158158', '159159', '160160', '161161', '162162', '163163', '164164', '165165', '166166', '167167', '168168', '169169', '170170', '171171', '172172', '173173', '174174', '175175', '176176', '177177', '178178', '179179', '180180', '181181', '182182', '183183', '184184', '18 ...
# 16793817782
